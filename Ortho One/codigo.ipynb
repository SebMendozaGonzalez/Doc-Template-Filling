# %%
import pandas as pd
from docx import Document

# %%
df = pd.read_csv("./info.csv")

df = df.iloc[:55]
df.columns = ['CaseNumber','ContactName','MedicalFacility','DateOfLoss','DateOfservice','ThroughDate','LawFirm','BillingAmount']

df
# Out:
# C:\Users\SGonzaleAdmin\AppData\Local\Temp\ipykernel_36364\3894956670.py:1: DtypeWarning: Columns (0,1,2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./info.csv")
#    CaseNumber          ContactName  \
# 0    SF-37445       Albert Menefee
# 1    SF-38467        Amanda Montes
# 2    SF-05501            Amy Beall
# 3    SF-30207        Artur Kazimiy
# 4    SF-42871       Barbara Parker
# 5    SF-42871       Barbara Parker
# 6    SF-53752     Bernardo Stanton
# 7    SF-39328       Brandyn Morris
# 8    SF-26922    Catherine Hudnall
# 9    SF-26922    Catherine Hudnall
# 10   SF-43436       Cheyenne Payne
# 11   SF-43436       Cheyenne Payne
# 12   SF-55987         Devon Toovey
# 13   SF-55987         Devon Toovey
# 14   SF-36459        Ellen McElgun
# 15   SF-36459        Ellen McElgun
# 16   SF-36459        Ellen McElgun
# 17   SF-56891         Emily Tucker
# 18   SF-08804       Gerald Bustion
# ...

# %%
def create_doc(df: pd.Dataframe) -> None:
    
    return None

# %%
doc = Document("./document_template.docx")

grouped_df = df.groupby('CaseNumber')

for CaseNumber, group in grouped_df:
    create_doc(group)
